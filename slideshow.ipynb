# %% [markdown]
# <center><h1>Analyse comparée d'images biomédicales en 3D</h1></center>
# <center><h3>au niveau cellulaire</h3></center>
#
# <br>
# <center><h2>Marianne Corvellec</h2></center>
# <center>
#     <img src="imgs/skimage_logo.png" width="300">&nbsp;&nbsp;
#     <img src="imgs/igdore_logo.png" width="300">
# </center>
#
# <center><h4>Séminaire du 26 mai 2026 — Laboratoire ICube, équipe IMAGeS ― Université de Strasbourg</h4></center>
